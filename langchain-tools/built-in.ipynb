# %%
from langchain_community.tools import DuckDuckGoSearchResults

search_tool = DuckDuckGoSearchResults()

result = search_tool.invoke('Reliance news january 2011')

print(result)
# Out:
# snippet: Reliance, Inc. to Announce Fourth Quarter and Full Year 2025 Results on Wednesday, February 18th Nov 6, 2025 4:05 pm EST, title: Press Releases - Reliance, Inc. (RS), link: https://investor.reliance.com/news-events/press-releases, snippet: Stay updated with the latest Reliance Industries press releases, financial results, strategic ventures, and corporate announcements. Read now!, title: Press Releases - Reliance Industries Limited, link: https://www.ril.com/news-media/press-releases, snippet: Reliance Industries could generate nearly Rs 90,000 crore in cumulative free cash flow over FY26-FY28 as its heavy investment cycle eases, brokerages say. Stronger earnings from energy and Jio, coupled with moderating capex, may reduce leverage and mark the beginning of a sustained cash flow and earnings upcycle., title: Reliance Industries News - The Economic Times, link: https://economictimes.indiatimes.com/reliance-industries-ltd/stocksupdate/companyid-13215.cms, snippet: Reliance Industries Limited (RIL) is one of the largest companies in India. It has businesses in energy, retail, telecom through Jio, and media & entertainment. In this article, you can check the complete Reliance Industries dividend, bonus, stock split, buyback and rights issue history from 1983 to 2026, along with the latest corporate action updates., title: Reliance Industries Dividend, Bonus, Split History 1983-2026, link: https://dividendbonus.com/reliance-industries-dividend-bonus-split-history/

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

result = shell_tool.invoke('ls')

print(result)
# Out:
# Executing command:
#  ls
# built-in.ipynb
