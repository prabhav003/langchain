# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage

# %%
@tool
def multiply(a:int, b:int)->int:
    '''Given 2 numbers a and b this tool returns their product'''
    return a*b

# %%
print(multiply.invoke({'a':3, 'b':4}))
# Out:
# 12

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'Given 2 numbers a and b this tool returns their product'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
# tool binding 

from dotenv import load_dotenv

load_dotenv()

llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation"
)

llm = ChatHuggingFace(llm=llm)

# %%
llm_with_tools = llm.bind_tools([multiply])

# %%
result = llm_with_tools.invoke('Hi how are you?')

result.content
# Out:
# "I'm a large language model, so I don't have emotions, but I'm functioning properly. How can I assist you?"

# %%
ans = llm_with_tools.invoke('Can you multiply 3 by 10')

ans.tool_calls[0]['args']
# Out:
# {'a': 3, 'b': 10}

# %% [markdown]
# # Tool Execution

# %%
result = multiply.invoke(ans.tool_calls[0]['args'])

result
# Out:
# 30

# %%
result = multiply.invoke(ans.tool_calls[0])

result
# Out:
# ToolMessage(content='30', name='multiply', tool_call_id='call_4J7fYxCigOcv2NFxLXG5x9tS')
